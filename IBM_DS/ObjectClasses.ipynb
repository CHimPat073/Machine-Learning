# %%
#creating Circle Class
class Circle:
    def __init__(self,radius,color):
        self.radius = radius
        self.color = color
    #Methods
    add=8
    def add_radius(self,add):
        self.radius += add
        return self.radius

RC= Circle(5,'red')
added_radius = RC.add_radius(RC.add)
print(added_radius)
print(RC.radius,RC.color)

dir(RC)  # to see all attributes and methods of the class
# Out:
# 13
# 13 red
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'add',
#  'add_radius',
#  'color',
#  'radius']

# %%
class Rectangle:
    def __init__(self,length,breadth,color):
        self.length = length
        self.breadth = breadth
        self.color = color
        
R1 = Rectangle(10,5,'blue')
print(R1.length,R1.breadth,R1.color)
# Out:
# 10 5 blue

# %%
import matplotlib.pyplot as plt
# %matplotlib inline  
class Circle(object):
    
    # Constructor
    def __init__(self, radius=3, color='blue'):
        self.radius = radius
        self.color = color 
    
    # Method
    def add_radius(self, r):
        self.radius = self.radius + r
        return(self.radius)
    
    # Method
    def drawCircle(self):
        plt.gca().add_patch(plt.Circle((0, 0), radius=self.radius, fc=self.color))
        plt.axis('scaled')
        plt.show()  

RedCircle = Circle(10, 'red')
RedCircle.add_radius(5)
RedCircle.drawCircle()

# %%
RedCircle.radius = 1
RedCircle.radius
# Out:
# 1

# %%
RedCircle.add_radius(1)
RedCircle.drawCircle()

# %%
BlueCircle = Circle(radius=100)

# %%
BlueCircle.radius
# Out:
# 100

# %%
BlueCircle.drawCircle()

# %%
class Rectangle(object):
    
    # Constructor
    def __init__(self, width=2, height=3, color='r'):
        self.height = height 
        self.width = width
        self.color = color
    
    # Method
    def drawRectangle(self):
        plt.gca().add_patch(plt.Rectangle((0, 0), self.width, self.height ,fc=self.color))
        plt.axis('scaled')
        plt.show()
        
R1 = Rectangle(10,5,'blue')
R1.drawRectangle()

# %%
R1.color
# Out:
# 'blue'

# %%
#Task-1. You are tasked with creating a Python program to represent vehicles using a class. 
# Each car should have attributes for maximum speed and mileage.

class Vehicle:
    def __init__(self, max_speed, mileage):
        self.max_speed = max_speed
        self.mileage = mileage

# %%
#Task-2. Update the class with the default color for all vehicles," white".
class Vehicle:
    def __init__(self, max_speed, mileage, color='white'):
        self.max_speed = max_speed
        self.mileage = mileage
        self.color = color

# %%
class Vehicle:
    

    def __init__(self, max_speed, mileage,color = "white"):
        self.max_speed = max_speed
        self.mileage = mileage
        self.color = color
        self.seating_capacity = None

    def assign_seating_capacity(self, seating_capacity):
        self.seating_capacity = seating_capacity
    
    def display(self):
        print("Properties of the Vehicle:")
        print("Color:", self.color)
        print("Maximum Speed:", self.max_speed)
        print("Mileage:", self.mileage)
        print("Seating Capacity:", self.seating_capacity)
        
v1= Vehicle(120, 15000)
v1.assign_seating_capacity(5)  
v1.display()
# Out:
# Properties of the Vehicle:
# Color: white
# Maximum Speed: 120
# Mileage: 15000
# Seating Capacity: 5

# %%
#ask-5. Additionally, you need to create two objects of the Vehicle class object that should have a max speed of 
# 200kmph and mileage of 20kmpl with five seating capacities, 
# and another car object should have a max speed of 180kmph and mileage of 25kmpl with four seating capacities.

class Vehicle:
    

    def __init__(self, max_speed, mileage,color = "white"):
        self.max_speed = max_speed
        self.mileage = mileage
        self.color = color
        self.seating_capacity = None

    def assign_seating_capacity(self, seating_capacity):
        self.seating_capacity = seating_capacity
    
    def display(self):
        print("Properties of the Vehicle:")
        print("Color:", self.color)
        print("Maximum Speed:", self.max_speed)
        print("Mileage:", self.mileage)
        print("Seating Capacity:", self.seating_capacity)

v1=Vehicle(200,20)
v1.assign_seating_capacity(5)
v1.display()

print(" ")
v2=Vehicle(200,20)
v2.assign_seating_capacity(4)
v2.display()
# Out:
# Properties of the Vehicle:
# Color: white
# Maximum Speed: 200
# Mileage: 20
# Seating Capacity: 5
#
# Properties of the Vehicle:
# Color: white
# Maximum Speed: 200
# Mileage: 20
# Seating Capacity: 4

# %%
class Circle(object):
    # Constructor
    def __init__(self, radius=3, color='blue'):
        self.radius = radius
        self.color = color
        
    # Method
    def add_radius(self, r):
        self.radius = self.radius + r
        return self.radius

CircleObject = Circle()

CircleObject.radius = 10
print(CircleObject.radius)
# Out:
# 10

# %%
class Vehicle:
    color = "white"


    def __init__(self, max_speed, mileage):
        self.max_speed = max_speed
        self.mileage = mileage
        self.seating_capacity = None


    def assign_seating_capacity(self, seating_capacity):
        self.seating_capacity = seating_capacity


V1 = Vehicle(150, 25)
print(V1.color)
# Out:
# white
